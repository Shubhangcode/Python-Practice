# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubhangcode/Python-Practice/blob/main/Project_marks_Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/student_habits_performance.csv')

# %%
import os

file_name = 'student_habits_performance.csv'
if file_name in os.listdir('.'):
    print(f"The file '{file_name}' has been successfully uploaded to the Colab environment.")
else:
    print(f"The file '{file_name}' is still not found in the Colab environment. Please ensure it has been uploaded correctly.")
# Out:
# The file 'student_habits_performance.csv' is still not found in the Colab environment. Please ensure it has been uploaded correctly.

# %%
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
# ...

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.head(2)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
df.isna().sum().sum()
# Out:
# np.int64(91)

# %%
df.dropna(inplace=True)

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# student_id                       0
# age                              0
# gender                           0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# part_time_job                    0
# attendance_percentage            0
# sleep_hours                      0
# diet_quality                     0
# exercise_frequency               0
# parental_education_level         0
# internet_quality                 0
# mental_health_rating             0
# extracurricular_participation    0
# exam_score                       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df.describe()
# Out:
#               age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  909.000000           909.000000          909.000000     909.000000
# mean    20.475248             3.538724            2.504620       1.830363
# std      2.302721             1.469730            1.164802       1.071251
# min     17.000000             0.000000            0.000000       0.000000
# 25%     18.000000             2.500000            1.700000       1.000000
# 50%     20.000000             3.500000            2.500000       1.800000
# 75%     22.000000             4.500000            3.300000       2.600000
# max     24.000000             8.300000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count             909.000000   909.000000          909.000000
# mean               83.880308     6.474037            3.051705
# std                 9.453622     1.218943            2.035632
# ...

# %%
df.describe(include='object')
# Out:
#        student_id gender part_time_job diet_quality parental_education_level  \
# count         909    909           909          909                      909
# unique        909      3             2            3                        3
# top         S1999   Male            No         Fair              High School
# freq            1    440           713          396                      392
#
#        internet_quality extracurricular_participation
# count               909                           909
# unique                3                             2
# top                Good                            No
# freq                410                           620

# %%
categorical_cols=["gender","part_time_job","parental_education_level","internet_quality","extracurricular_participation"]

# %%
for cols in categorical_cols:
    print(f"Value counts for {cols}:/n{df[cols].value_counts()}/n")
# Out:
# Value counts for gender:/ngender
# Male      440
# Female    433
# Other      36
# Name: count, dtype: int64/n
# Value counts for part_time_job:/npart_time_job
# No     713
# Yes    196
# Name: count, dtype: int64/n
# Value counts for parental_education_level:/nparental_education_level
# High School    392
# Bachelor       350
# Master         167
# Name: count, dtype: int64/n
# Value counts for internet_quality:/ninternet_quality
# Good       410
# Average    352
# Poor       147
# Name: count, dtype: int64/n
# Value counts for extracurricular_participation:/nextracurricular_participation
# No     620
# Yes    289
# Name: count, dtype: int64/n

# %%
df.hist(bins=20, edgecolor='black')
plt.tight_layout()
plt.show()

# %%
for col in categorical_cols:
  sns.countplot(data=df, x=col)
  plt.title(f"Distribution of {col}")
  plt.xticks(rotation=45)
  plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                             age  study_hours_per_day  social_media_hours  \
# age                    1.000000             0.007150           -0.023854
# study_hours_per_day    0.007150             1.000000            0.007364
# social_media_hours    -0.023854             0.007364            1.000000
# netflix_hours          0.005841            -0.014493            0.011865
# attendance_percentage -0.030203             0.028967            0.049356
# sleep_hours            0.040498            -0.026241            0.026861
# exercise_frequency    -0.005718            -0.024708           -0.023975
# mental_health_rating  -0.052137            -0.015896           -0.000417
# exam_score            -0.012833             0.822950           -0.171672
#
#                        netflix_hours  attendance_percentage  sleep_hours  \
# age                         0.005841              -0.030203     0.040498
# study_hours_per_day        -0.014493               0.028967    -0.026241
# ...

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True,cmap="coolwarm",fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
df.describe().columns
# Out:
# Index(['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
#        'attendance_percentage', 'sleep_hours', 'exercise_frequency',
#        'mental_health_rating', 'exam_score'],
#       dtype='object')

# %%
num_features=['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
       'attendance_percentage', 'sleep_hours', 'exercise_frequency',
       'mental_health_rating', 'exam_score']

# %%
for feature in num_features:
  sns.scatterplot(data = df, x=feature, y='exam_score')
  plt.title(f"{feature} vs Exams Score")
  plt.show()

# %%
for col in categorical_cols:
  sns.boxplot(data=df, x=col, y='exam_score')
  plt.title(f" Exams Score by {col}")
  plt.xticks(rotation=45)
  plt.show()

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %%
df.head(2)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0

# %%
features = ["study_hours_per_day",'attendance_percentage','sleep_hours', 'mental_health_rating','part_time_job',]

# %%
target = "exam_score"

# %%
df_model = df[features + [target]].copy()

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  sleep_hours  \
# 0                    0.0                   85.0          8.0
# 1                    6.9                   97.3          4.6
# 2                    1.4                   94.8          8.0
# 3                    1.0                   71.0          9.2
# 4                    5.0                   90.9          4.9
# ..                   ...                    ...          ...
# 995                  2.6                   77.0          7.5
# 996                  2.9                   86.0          6.8
# 997                  3.0                   61.9          6.5
# 998                  5.4                  100.0          7.6
# 999                  4.3                   89.4          7.1
#
#      mental_health_rating part_time_job  exam_score
# 0                       8            No        56.2
# 1                       8            No       100.0
# 2                       1            No        34.3
# ...

# %%
le = LabelEncoder()

# %%
df_model["part_time_job"] = le.fit_transform(df_model["part_time_job"])

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  sleep_hours  \
# 0                    0.0                   85.0          8.0
# 1                    6.9                   97.3          4.6
# 2                    1.4                   94.8          8.0
# 3                    1.0                   71.0          9.2
# 4                    5.0                   90.9          4.9
# ..                   ...                    ...          ...
# 995                  2.6                   77.0          7.5
# 996                  2.9                   86.0          6.8
# 997                  3.0                   61.9          6.5
# 998                  5.4                  100.0          7.6
# 999                  4.3                   89.4          7.1
#
#      mental_health_rating  part_time_job  exam_score
# 0                       8              0        56.2
# 1                       8              0       100.0
# 2                       1              0        34.3
# ...

# %%
X = df_model[features]

# %%
y = df_model[target]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, )

# %%
len(y_test)
# Out:
# 182

# %%
len(y_train)
# Out:
# 727

# %%
models = {
    "LinearRegression": {
        "model": LinearRegression(),
        "params": {}
    },
    "DecisionTree": {
        "model": DecisionTreeRegressor(),
        "params":{"max_depth": [3,5,10], "min_samples_split": [2,5]}
    },
    "RandomForest":{
        "model":  RandomForestRegressor(),
        "params":{"n_estimators": [50, 100], "max_depth": [5,10]}
    }
}

# %%
best_models = []

# %%
for name, config in models.items():
  print(f"Training {name}...")
  grid_search = GridSearchCV(config["model"], config["params"], cv=5, scoring="neg_mean_squared_error")
  grid_search.fit(X_train, y_train)

  y_pred = grid_search.predict(X_test)
  rmse = np.sqrt(mean_squared_error(y_test, y_pred))
  r2 = r2_score(y_test, y_pred)

  best_models.append({
      "model_name": name,
      "best_params": grid_search.best_params_,
      "best_score": grid_search.best_score_,
      "rmse":rmse,
      "r2":r2

  })
# Out:
# Training LinearRegression...
# Training DecisionTree...
# Training RandomForest...

# %%
results_df = pd.DataFrame(best_models)

# %%
results_df.sort_values(by="rmse")
# Out:
#          model_name                               best_params  best_score  \
# 0  LinearRegression                                        {}  -53.752119
# 2      RandomForest      {'max_depth': 5, 'n_estimators': 50}  -58.883834
# 1      DecisionTree  {'max_depth': 5, 'min_samples_split': 5}  -70.385551
#
#        rmse        r2
# 0  7.462019  0.791158
# 2  7.842283  0.769331
# 1  8.651600  0.719265

# %%
import joblib
best_row = results_df.sort_values(by="rmse").iloc[0]

# %%
best_row
# Out:
# model_name     LinearRegression
# best_params                  {}
# best_score           -53.752119
# rmse                   7.462019
# r2                     0.791158
# Name: 0, dtype: object

# %%
best_model_name = best_row["model_name"]

# %%
best_model_name
# Out:
# 'LinearRegression'

# %%
best_model_config = models[best_model_name]

# %%
best_model_name
# Out:
# 'LinearRegression'

# %%
final_model = best_model_config["model"]

# %%
final_model.fit(X,y)
# Out:
# LinearRegression()

# %%
joblib.dump(final_model, "best_model.pkl")
# Out:
# ['best_model.pkl']

# %%
joblib.load("best_model.pkl").predict(X_test)
# Out:
# array([ 58.56807717,  77.3074474 ,  79.77697389,  68.64068393,
#         58.73539837,  58.11862611,  76.0418415 ,  77.1562697 ,
#         44.81898792, 105.61559246,  55.7323605 ,  76.60690732,
#         66.55221819,  63.21934429,  49.45186634,  74.7216201 ,
#         41.50768325, 105.01596237,  57.67033365,  47.41966756,
#         74.89289694,  66.71216009,  54.20184513,  77.22484193,
#         62.03082708,  60.6209758 ,  69.85675881,  77.09472949,
#         87.18702105,  69.78701234,  86.71282094,  66.54212873,
#         82.51642869,  66.21786679,  64.33742269,  96.07396925,
#         73.53456232,  85.05249299,  66.00468079,  72.93089446,
#         57.380995  ,  61.85054984, 100.28724338,  79.59311223,
#         86.30137744,  73.19341212,  79.32808448,  55.45149562,
#         68.39919847,  83.44386551,  74.29479694,  86.41513985,
#         55.72437836,  56.51857377,  67.77673736,  86.92298316,
#         74.5771561 ,  91.82549796,  75.00352966,  74.26344109,
# ...

# %%
# %%writefile app.py
import streamlit as st
import numpy as np
import joblib
import warnings
warnings.filterwarnings("ignore")

# Load the trained model
model = joblib.load('best_model.pkl')

st.title('Student Exam Score Prediction')
study_hours= st.slider("Study Hours per Day", 0.0, 12.0, 2.0)
attendence= st.slider("Attendence Percentage", 0.0, 100.0, 80.0)
sleep_hours= st.slider("Sleep Hours", 0.0, 12.0, 7.0)
mental_health= st.slider("Mental Health Rating", 1.0, 10.0, 5.0)
part_time_job= st.selectbox("Part Time Job", ["Yes", "No"])
ptj_encoded = 1 if part_time_job == "Yes" else 0

if st.button("Predict Exam Score"):
    input_data = np.array([[study_hours,attendence,sleep_hours,mental_health,ptj_encoded]])
    prediction = model.predict(input_data)[0]

    prediction = max(0,min(100,prediction))
    st.success(f'Predicted Exam Score: {prediction:.2f}')
# You can add more Python code here.
# For example, to load your model:
# import joblib
# loaded_model = joblib.load('best_model.pkl')
# print('Model loaded successfully!')
# Out:
# Writing app.py

# %%
import os
# !pip install streamlit pyngrok --quiet

from pyngrok import ngrok

# Prompt the user for their ngrok authtoken
# You can get your authtoken from https://dashboard.ngrok.com/get-started/your-authtoken
print("Please enter your ngrok authtoken (found at https://dashboard.ngrok.com/get-started/your-authtoken):")
NGROK_AUTH_TOKEN = input()

if NGROK_AUTH_TOKEN:
    ngrok.set_auth_token(NGROK_AUTH_TOKEN)
    print("Ngrok authtoken set successfully.")
else:
    print("No ngrok authtoken provided. ngrok may not function correctly.")

# Connect ngrok to port 8501 where Streamlit app will run
public_url = ngrok.connect(8501)
print(f"Streamlit App URL: {public_url}")

# Run the Streamlit app in the background
# !streamlit run app.py &>/dev/null&
# Out:
# Please enter your ngrok authtoken (found at https://dashboard.ngrok.com/get-started/your-authtoken):
# 37tgD3WbiK9vxByOlN8WiILbM49_6y862dQdvsAFAYedW7Kvg
# Ngrok authtoken set successfully.
# Streamlit App URL: NgrokTunnel: "https://ostiolar-ghast-flavia.ngrok-free.dev" -> "http://localhost:8501"

# %%
import os
# !pip install streamlit pyngrok --quiet

from pyngrok import ngrok
from pyngrok.exception import PyngrokNgrokError # Import PyngrokNgrokError correctly

# Kill any existing ngrok processes to ensure a clean start
ngrok.kill()

# Prompt the user for their ngrok authtoken
# You can get your authtoken from https://dashboard.ngrok.com/get-started/your-authtoken
print("Please enter your ngrok authtoken (it should start with 'authtoken_'):")
NGROK_AUTH_TOKEN = input().strip()

if NGROK_AUTH_TOKEN:
    ngrok.set_auth_token(NGROK_AUTH_TOKEN)
    print("Ngrok authtoken set successfully.")
else:
    print("No ngrok authtoken provided. ngrok will not function correctly.")

public_url = None
try:
    # Connect ngrok to port 8501 where Streamlit app will run
    public_url = ngrok.connect(8501)
    print(f"Streamlit App URL: {public_url}")

    # Run the Streamlit app in the background
    # !streamlit run app.py &>/dev/null&
except PyngrokNgrokError as e: # Use the correctly imported exception
    print(f"Error connecting to ngrok: {e}")
    print("Please ensure your ngrok authtoken is correct and try again. It typically starts with 'authtoken_'.")
    print("You can find your authtoken at https://dashboard.ngrok.com/get-started/your-authtoken")
# Out:
# Please enter your ngrok authtoken (it should start with 'authtoken_'):
# 37tgD3WbiK9vxByOlN8WiILbM49_6y862dQdvsAFAYedW7Kvg
# Ngrok authtoken set successfully.
# Streamlit App URL: NgrokTunnel: "https://ostiolar-ghast-flavia.ngrok-free.dev" -> "http://localhost:8501"

# %% [markdown]
# ## The public URL to access the Streamlit application is https://ostiolar-ghast-flavia.ngrok-free.dev. The task is complete.**bold text**
